# %% [markdown]
# # Convolutional Neural Networks
#
# ## Preliminaries
#
# In this practical session you will implement and train several Convolutional Neural Networks (CNNs) using the Keras framework with a Tensorflow backend. If you are not already familiar with Keras, you can go over the [following tutorial](https://github.com/tueimage/essential-skills/blob/master/keras.md). More detailed information on the different functionalities can be found in the [Keras library documentation](https://keras.io/).
#
# Note that for this set of exercise CPU-only Tensorflow, which you should already have installed, is sufficient (i.e. GPU-support is not required but it will make your experiments run faster).
#
# You are also required to use the `gryds` package for data augmentation that you can install directly from git: `pip install git+https://github.com/tueimage/gryds/`.
#
# You also have to install the Keras deep learning framework (if you have not done so already) by running `conda install keras`. Note that there are two implementations of Keras, one from https://keras.io/ and another one that ships with Tensorflow. Here we use the former.

# %% [markdown]
# ## MNIST
# We will first train a simple CNN to classify handwritten digits using the MNIST dataset. This dataset is often referred to as the "Hello world!" example of deep learning because it can be used to quickly illustrate a small neural network in action (and obtain a decent classification accuracy in the process). More information on it can be found [here](http://yann.lecun.com/exdb/mnist/).
#
# First, let's load the dataset and visualize some images.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# load the MNIST the dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# scale the image intensities to the 0-1 range
x_train = (x_train / 255.0).astype(np.float32)
x_test = (x_test / 255.0).astype(np.float32)

# convert the data to channel-last
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# convert the labels to one-hot encoded
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

def plot_images(images, dim=(10, 10), figsize=(10, 10), title=''):
    
    plt.figure(figsize=figsize)
    
    for i in range(images.shape[0]):
        plt.subplot(dim[0], dim[1], i+1)
        plt.imshow(images[i], interpolation='nearest', cmap='gray_r')
        plt.axis('off')
    
    plt.tight_layout()
    plt.suptitle(title)
    plt.show()
    
plot_images(x_train[np.random.randint(0, x_train.shape[0], size=100)].reshape(100, 28, 28))

# %% [markdown]
# The MNIST classification task is quite simple: given an image, predict the digit that it contains. Thus, this is a 10-class classification problem.
#
# Let's define a simple network for the handwritten digit classification.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1179776
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile and train the network (note that this could take a while).

# %%
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam

model.compile(loss=categorical_crossentropy, optimizer=Adam(), metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=128,
          epochs=12,
          verbose=1,
          validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# Now that the model is trained, we can evaluate its performance on the independent test dataset.

# %%
score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# ## U-Net
# The U-Net convolutional neural network architecture was first developed for biomedical image segmentation and is to this day one of the most widely used methods for image segmentation. The details of the architecture can be found in the [original paper](https://arxiv.org/abs/1505.04597). In this practical we will build and train a U-Net network that is able to segment blood vessels in retinal images.
#
# ### Loading and visualizing the data
# The data for this task is taken from the [DRIVE](https://www.isi.uu.nl/Research/Databases/DRIVE/index.php) database. It consists of photographs of the retina, where the goal is to segment the blood vessels within. The dataset has a total of 40 photographs, divided in 20 images for training and 20 for testing. The images corresponding to the DRIVE test set can be found [here](https://www.dropbox.com/s/zk51wgupimw7jd9/DRIVE.zip?dl=0).
#
# Let's load the training set and visualize an image with the corresponding blood vessel segmentation. For training we will divide the data in a training and a validation set to monitor the model during training.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from glob import glob
from unet_utils import load_data

# location of the DRIVE dataset
#data_folder = 'C:/Users/20192547/8dm50-machine-learning/practicals/data/DRIVE'
#data_folder_training=data_folder + '/training/images/*.tif'
train_paths = glob('C:/Users/20192547/8dm50-machine-learning/practicals/data/DRIVE/training/images/*.tif')

images, masks, segmentations = load_data(train_paths)

# print the shape of image dataset
print(images.shape)

plt.figure(figsize=(10, 8))

plt.subplot(1, 2, 1)
plt.title("Image of the retina")
plt.axis('off')
plt.imshow(images[0])

plt.subplot(1, 2, 2)
plt.title("Ground truth vessel segmentation")
plt.axis('off')
plt.imshow(segmentations[0][:, :, 0])

plt.show()

# divide in training and validation
train_images, val_images, train_masks, val_masks, train_segmentations, val_segmentations = train_test_split(
    images, masks, segmentations, test_size=0.2, random_state=7)

# print the shape of the training and valudation datasets
print(train_images.shape)
print(train_masks.shape)
print(train_segmentations.shape)
print(val_images.shape)
print(val_masks.shape)
print(val_segmentations.shape)
# Out:
# (20, 584, 565, 3)
# (16, 584, 565, 3)
# (16, 584, 565, 1)
# (16, 584, 565, 1)
# (4, 584, 565, 3)
# (4, 584, 565, 1)
# (4, 584, 565, 1)

# %% [markdown]
# ### Training a U-Net model
#
# You are already provided with implementation of the U-Net architecture in `unet_model.py`. This is a modular implementation and can be used to generate U-Net architectures with a variety of hyperparameters such as depth and number of feature maps. Before using the model, examine the code and documentation and make sure that you understand all the details.
#
# We will train a U-Net model using smaller patches extracted from the training images. Training the images on smaller patches requires less computation power and results in a more varied training dataset (it has the effect of data augmentation by image translation). Because a U-Net is a fully convolutional network it can be evaluated on inputs of different size (the output size will change according to the input size). Thus, although the model will be trained on smaller patches it can still be used to segment larger images with one pass through the model.

# %%
from unet_utils import extract_patches, preprocessing

# work with 32x32 patches
patch_size = (32, 32)

# 200 patches per image
patches_per_im = 200

# visualize a couple of patches as a visual check
patches, patches_segmentations = extract_patches(train_images, train_segmentations, patch_size, patches_per_im=1, seed=7)

print(patches.shape)

fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 12))

for i in range(0, 3):
    axes[i, 0].axis('off')
    axes[i, 0].imshow(patches[i])
    axes[i, 1].axis('off')
    axes[i, 1].imshow(patches_segmentations[i][:, :, 0])
    axes[i, 2].axis('off')
    axes[i, 2].imshow(patches[i+5])
    axes[i, 3].axis('off')
    axes[i, 3].imshow(patches_segmentations[i+5][:, :, 0])

plt.show()
# Out:
# (16, 32, 32, 3)

# %%
# pad the validation data to fit the U-Net model
# images of shape (584, 565) shape result in concatenation error due to the odd number of columns

print("Old shape:", val_images.shape)

val_images, val_masks, val_segmentations = preprocessing(
    val_images, 
    val_masks, 
    val_segmentations, 
    desired_shape=(584, 584))
    
print("New shape:", val_images.shape)
# Out:
# Old shape: (4, 584, 565, 3)
# New shape: (4, 584, 584, 3)

# %%
import os
from unet_model import unet
from unet_utils import datagenerator
from keras.models import load_model
from tensorflow.keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# use a single training image, to better demonstrate the effects of data augmentation
X_train, y_train = np.expand_dims(train_images[0], axis=0), np.expand_dims(train_segmentations[0], axis=0)

print(X_train.shape)
print(y_train.shape)

# hyperparameters
depth = 3
channels = 32
use_batchnorm = True
batch_size = 64
epochs = 250
steps_per_epoch = int(np.ceil((patches_per_im * len(train_images)) / batch_size))

# work with 32x32 patches
patch_size = (32, 32)
# 200 patches per image
patches_per_im = 200

# initialize model
model = unet(input_shape=(None, None, 3), depth=depth, channels=channels, batchnorm=use_batchnorm)

# print a summary of the model
# model.summary(line_length=120)

# compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# stop the training if the validation loss does not increase for 15 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# train the model with the data generator, and save the training history
history = model.fit_generator(datagenerator(X_train, y_train, patch_size, patches_per_im, batch_size),
                              validation_data=(val_images, val_segmentations),
                              steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=2,
                              callbacks=[early_stopping])
# Out:
# (1, 584, 565, 3)
# (1, 584, 565, 1)
# C:\Users\20192547\Anaconda3\envs\8dm50_2\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/250
# 50/50 - 21s - loss: 0.4963 - accuracy: 0.8460 - val_loss: 0.3883 - val_accuracy: 0.9211
# Epoch 2/250
# 50/50 - 18s - loss: 0.3082 - accuracy: 0.9491 - val_loss: 0.2950 - val_accuracy: 0.9211
# Epoch 3/250
# 50/50 - 17s - loss: 0.2373 - accuracy: 0.9552 - val_loss: 0.2878 - val_accuracy: 0.9198
# Epoch 4/250
# 50/50 - 17s - loss: 0.1776 - accuracy: 0.9589 - val_loss: 0.2887 - val_accuracy: 0.9212
# Epoch 5/250
# 50/50 - 17s - loss: 0.1574 - accuracy: 0.9584 - val_loss: 0.3071 - val_accuracy: 0.9211
# Epoch 6/250
# 50/50 - 16s - loss: 0.1415 - accuracy: 0.9597 - val_loss: 0.3165 - val_accuracy: 0.9213
# Epoch 7/250
# 50/50 - 17s - loss: 0.1351 - accuracy: 0.9585 - val_loss: 0.3505 - val_accuracy: 0.9118
# Epoch 8/250
# 50/50 - 16s - loss: 0.1443 - accuracy: 0.9552 - val_loss: 4.2070 - val_accuracy: 0.2365
# Epoch 9/250
# 50/50 - 17s - loss: 0.1247 - accuracy: 0.9598 - val_loss: 0.2497 - val_accuracy: 0.9370
# Epoch 10/250
# 50/50 - 17s - loss: 0.1117 - accuracy: 0.9627 - val_loss: 0.2014 - val_accuracy: 0.9398
# Epoch 11/250
# 50/50 - 18s - loss: 0.1110 - accuracy: 0.9619 - val_loss: 0.2892 - val_accuracy: 0.9168
# Epoch 12/250
# 50/50 - 17s - loss: 0.1097 - accuracy: 0.9626 - val_loss: 0.1771 - val_accuracy: 0.9446
# Epoch 13/250
# 50/50 - 17s - loss: 0.1026 - accuracy: 0.9642 - val_loss: 0.1763 - val_accuracy: 0.9447
# Epoch 14/250
# 50/50 - 18s - loss: 0.0994 - accuracy: 0.9649 - val_loss: 0.1337 - val_accuracy: 0.9530
# Epoch 15/250
# 50/50 - 18s - loss: 0.0978 - accuracy: 0.9649 - val_loss: 0.1346 - val_accuracy: 0.9491
# Epoch 16/250
# 50/50 - 18s - loss: 0.0971 - accuracy: 0.9651 - val_loss: 0.2725 - val_accuracy: 0.8814
# Epoch 17/250
# 50/50 - 18s - loss: 0.0913 - accuracy: 0.9672 - val_loss: 0.2071 - val_accuracy: 0.9230
# Epoch 18/250
# 50/50 - 18s - loss: 0.0911 - accuracy: 0.9669 - val_loss: 0.1794 - val_accuracy: 0.9221
# Epoch 19/250
# 50/50 - 19s - loss: 0.0927 - accuracy: 0.9661 - val_loss: 0.1370 - val_accuracy: 0.9500
# Epoch 20/250
# 50/50 - 16s - loss: 0.0882 - accuracy: 0.9675 - val_loss: 0.1741 - val_accuracy: 0.9321
# Epoch 21/250
# 50/50 - 21s - loss: 0.0889 - accuracy: 0.9674 - val_loss: 0.2299 - val_accuracy: 0.9196
# Epoch 22/250
# 50/50 - 20s - loss: 0.0907 - accuracy: 0.9665 - val_loss: 0.2338 - val_accuracy: 0.9072
# Epoch 23/250
# 50/50 - 19s - loss: 0.0886 - accuracy: 0.9669 - val_loss: 0.7159 - val_accuracy: 0.7356
# Epoch 24/250
# 50/50 - 23s - loss: 0.0892 - accuracy: 0.9666 - val_loss: 0.3699 - val_accuracy: 0.8609
# Epoch 25/250
# 50/50 - 28s - loss: 0.0869 - accuracy: 0.9673 - val_loss: 0.1455 - val_accuracy: 0.9472
# Epoch 26/250
# 50/50 - 23s - loss: 0.0914 - accuracy: 0.9662 - val_loss: 0.7975 - val_accuracy: 0.7576
# Epoch 27/250
# 50/50 - 27s - loss: 0.0874 - accuracy: 0.9671 - val_loss: 0.2089 - val_accuracy: 0.9225
# Epoch 28/250
# 50/50 - 22s - loss: 0.0808 - accuracy: 0.9697 - val_loss: 0.2000 - val_accuracy: 0.9227
# Epoch 29/250
# 50/50 - 27s - loss: 0.0826 - accuracy: 0.9686 - val_loss: 0.1922 - val_accuracy: 0.9283

# %% [markdown]
# ### Visualizing the segmentation results

# %%
# run the model on one test image and show the results
from unet_utils import preprocessing

# test data paths
impaths_test = glob('C:/Users/20192547/8dm50-machine-learning/practicals/data/DRIVE/test/images/*.tif')

# load data
test_images, test_masks, test_segmentations = load_data(impaths_test, test=True)

# pad the data to fit the U-Net model
test_images, test_masks, test_segmentations = preprocessing(test_images, test_masks, test_segmentations, 
                                                            desired_shape=(584, 584))

# use a single image to evaluate
X_test, y_test = np.expand_dims(test_images[0], axis=0), np.expand_dims(test_masks[0], axis=0)

# predict test samples
test_prediction = model.predict(X_test, batch_size=4)

# visualize the test result
plt.figure(figsize=(12, 10))

plt.subplot(1, 3, 1)
plt.title("Image of the retina")
plt.axis('off')
plt.imshow(test_images[0])

plt.subplot(1, 3, 2)
plt.title("Ground truth vessel segmentation")
plt.axis('off')
plt.imshow(test_segmentations[0][:, :, 0])

plt.subplot(1, 3, 3)
plt.title("Predicted vessel segmentation")
plt.axis('off')
plt.imshow(test_prediction[0, :, :, 0])

plt.show()

# %% [markdown]
# ## U-Net architecture
#
# <font color='#770a0a'> What is the role of the skip connections in the U-Net neural network architecture? Will it be possible to train the exact same architecture with the skip connections omitted? If yes, what would be the expected result? If no, what would be the cause of the error?</font>
#
# *The skip connections allow for saved copies of the features of the symmetrical part in the encoder to concatenate with their corresponding decoder stage. The upscaled intermediate features contain more area information, while encoder features offer finer spatial details, which is crucial for precise segmentation.*
#
# *It is possible to omit the skip connections, however this will significantly impair segmentation quality. The decoder will completely rely on the information of the intermediate features, potentially sacrificing spatial details. The model will also struggle to accurately delineate objects, leading to taking longer to train and using more layers to attain comparable performance metrics as the Unet architecture.*

# %% [markdown]
# ## Data augmentation
#
# <font color='#770a0a'>Why does data augmentation result in less overfitting? Can data augmentation be applied to the test samples? If yes, towards what goal? If no, what is preventing that?</font>
#
# *Overfitting can be reduced by increasing the size of the existing dataset. Data augmentation does this by applying image transformations.*
#
# Implement random brightness augmentation of the image data by adding a random offset to the image intensity before passing them trough the network at training time. Train a model with random brightness augmentation and compare it to the baseline above.
#
# Implement data augmentation procedure that in addition to brightness augmentation also performs b-spline geometric augmentation using the [`gryds`](https://github.com/tueimage/gryds) package (you can look at the documentation of the package for an example on how to do that). Compare the new model with the baseline and the model that only performs brightness augmentation.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#import cv2
#import numpy as np
import gryds

def brightness_augmentation(image):
    # Generate a random brightness offset between -0.2 and 0.2
    brightness_offset = np.random.uniform(low=-0.2, high=0.2)
    # Add the offset to the image intensity
    augmented_image = tf.image.adjust_brightness(image, brightness_offset)
    return augmented_image

def b_spline_geometric_augmentation(image):
    # Define a random 3x3 B-spline grid for a 2D image:
    random_grid = np.random.rand(3, 3, 3,3)
    # Define a B-spline transformation object
    bspline = gryds.BSplineTransformation(random_grid)
    # Define an interpolator object for the image:
    interpolator = gryds.Interpolator(image)
    # Transform the image using the B-spline transformation
    transformed_image = interpolator.transform(bspline)
    return transformed_image

# %%
#
train_images_aug=train_images
train_images_spline=train_images
n=0;
for im in train_images:
    #Only brightness augmentation
    augmented_image=brightness_augmentation(im) 
    #brightness and b-spline augmentation
    spline_image=b_spline_geometric_augmentation(augmented_image) 
    train_images_aug[n]=augmented_image
    train_images_spline[n]=spline_image
    n=n+1;

# %%
# initialize model
brightness_model = unet(input_shape=(None, None, 3), depth=depth, channels=channels, batchnorm=use_batchnorm)
# compile the model
brightness_model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# initialize model
bspline_model = unet(input_shape=(None, None, 3), depth=depth, channels=channels, batchnorm=use_batchnorm)
# compile the model
bspline_model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %%
#brightness augmented
patches_aug, patches_segmentations_aug = extract_patches(train_images_aug, train_segmentations, patch_size, patches_per_im=1, seed=7)
# use a single training image, to better demonstrate the effects of data augmentation
X_train_aug, y_train_aug = np.expand_dims(train_images_aug[0], axis=0), np.expand_dims(train_segmentations[0], axis=0)

#spline augmented
patches_spline, patches_segmentations_spline = extract_patches(train_images_spline, train_segmentations, patch_size, patches_per_im=1, seed=7)
# use a single training image, to better demonstrate the effects of data augmentation
X_train_spline, y_train_spline = np.expand_dims(train_images_spline[0], axis=0), np.expand_dims(train_segmentations[0], axis=0)

# %%
# Train the baseline model
brightness_history = brightness_model.fit(datagenerator(X_train_aug, y_train_aug, patch_size, patches_per_im, batch_size),
                              validation_data=(val_images, val_segmentations),
                              steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=2,
                              callbacks=[early_stopping])
# Out:
# Epoch 1/250
# 50/50 - 20s - loss: 0.6470 - accuracy: 0.7445 - val_loss: 0.5760 - val_accuracy: 0.9211
# Epoch 2/250
# 50/50 - 17s - loss: 0.5202 - accuracy: 0.9027 - val_loss: 0.4413 - val_accuracy: 0.9211
# Epoch 3/250
# 50/50 - 17s - loss: 0.4090 - accuracy: 0.9072 - val_loss: 0.3527 - val_accuracy: 0.9211
# Epoch 4/250
# 50/50 - 17s - loss: 0.3398 - accuracy: 0.9088 - val_loss: 0.3717 - val_accuracy: 0.9211
# Epoch 5/250
# 50/50 - 18s - loss: 0.3215 - accuracy: 0.9040 - val_loss: 0.3597 - val_accuracy: 0.9211
# Epoch 6/250
# 50/50 - 18s - loss: 0.3059 - accuracy: 0.9079 - val_loss: 0.2884 - val_accuracy: 0.9211
# Epoch 7/250
# 50/50 - 20s - loss: 0.3123 - accuracy: 0.9041 - val_loss: 0.2988 - val_accuracy: 0.9211
# Epoch 8/250
# 50/50 - 22s - loss: 0.2920 - accuracy: 0.9129 - val_loss: 0.3020 - val_accuracy: 0.9211
# Epoch 9/250
# 50/50 - 23s - loss: 0.3039 - accuracy: 0.9077 - val_loss: 0.7735 - val_accuracy: 0.9211
# Epoch 10/250
# 50/50 - 22s - loss: 0.3038 - accuracy: 0.9077 - val_loss: 1.1119 - val_accuracy: 0.9211
# Epoch 11/250
# 50/50 - 25s - loss: 0.2970 - accuracy: 0.9100 - val_loss: 0.9948 - val_accuracy: 0.9211
# Epoch 12/250
# 50/50 - 20s - loss: 0.3019 - accuracy: 0.9082 - val_loss: 0.6300 - val_accuracy: 0.9211
# Epoch 13/250
# 50/50 - 19s - loss: 0.2962 - accuracy: 0.9106 - val_loss: 0.3033 - val_accuracy: 0.9209
# Epoch 14/250
# 50/50 - 21s - loss: 0.3054 - accuracy: 0.9074 - val_loss: 0.3027 - val_accuracy: 0.9211
# Epoch 15/250
# 50/50 - 18s - loss: 0.3035 - accuracy: 0.9072 - val_loss: 0.3548 - val_accuracy: 0.9211
# Epoch 16/250
# 50/50 - 20s - loss: 0.2967 - accuracy: 0.9103 - val_loss: 1.1973 - val_accuracy: 0.9211
# Epoch 17/250
# 50/50 - 21s - loss: 0.3018 - accuracy: 0.9087 - val_loss: 0.3669 - val_accuracy: 0.9211
# Epoch 18/250
# 50/50 - 18s - loss: 0.3063 - accuracy: 0.9062 - val_loss: 1.1834 - val_accuracy: 0.9211
# Epoch 19/250
# 50/50 - 21s - loss: 0.3045 - accuracy: 0.9069 - val_loss: 2.0948 - val_accuracy: 0.3901
# Epoch 20/250
# 50/50 - 20s - loss: 0.3046 - accuracy: 0.9067 - val_loss: 0.9335 - val_accuracy: 0.8871
# Epoch 21/250
# 50/50 - 22s - loss: 0.3052 - accuracy: 0.9066 - val_loss: 1.2585 - val_accuracy: 0.9029

# %%
bspline_history = bspline_model.fit(datagenerator(X_train_spline, y_train_spline, patch_size, patches_per_im, batch_size),
                              validation_data=(val_images, val_segmentations),
                              steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=2,
                              callbacks=[early_stopping])
# Out:
# Epoch 1/250
# 50/50 - 16s - loss: 0.6417 - accuracy: 0.7566 - val_loss: 0.5750 - val_accuracy: 0.9211
# Epoch 2/250
# 50/50 - 17s - loss: 0.5092 - accuracy: 0.9045 - val_loss: 0.4310 - val_accuracy: 0.9211
# Epoch 3/250
# 50/50 - 18s - loss: 0.4009 - accuracy: 0.9062 - val_loss: 0.3343 - val_accuracy: 0.9211
# Epoch 4/250
# 50/50 - 16s - loss: 0.3326 - accuracy: 0.9093 - val_loss: 0.2918 - val_accuracy: 0.9211
# Epoch 5/250
# 50/50 - 18s - loss: 0.3080 - accuracy: 0.9106 - val_loss: 0.2866 - val_accuracy: 0.9211
# Epoch 6/250
# 50/50 - 19s - loss: 0.3032 - accuracy: 0.9093 - val_loss: 0.3050 - val_accuracy: 0.9211
# Epoch 7/250
# 50/50 - 17s - loss: 0.3100 - accuracy: 0.9056 - val_loss: 0.3060 - val_accuracy: 0.9211
# Epoch 8/250
# 50/50 - 19s - loss: 0.3070 - accuracy: 0.9072 - val_loss: 0.2792 - val_accuracy: 0.9211
# Epoch 9/250
# 50/50 - 19s - loss: 0.2989 - accuracy: 0.9107 - val_loss: 0.3289 - val_accuracy: 0.9099
# Epoch 10/250
# 50/50 - 18s - loss: 0.3013 - accuracy: 0.9092 - val_loss: 0.4268 - val_accuracy: 0.9165
# Epoch 11/250
# 50/50 - 18s - loss: 0.2961 - accuracy: 0.9105 - val_loss: 0.4208 - val_accuracy: 0.9016
# Epoch 12/250
# 50/50 - 19s - loss: 0.2901 - accuracy: 0.9132 - val_loss: 1.8989 - val_accuracy: 0.5316
# Epoch 13/250
# 50/50 - 20s - loss: 0.3017 - accuracy: 0.9086 - val_loss: 2.4997 - val_accuracy: 0.9211
# Epoch 14/250
# 50/50 - 18s - loss: 0.3068 - accuracy: 0.9061 - val_loss: 0.5941 - val_accuracy: 0.9045
# Epoch 15/250
# 50/50 - 20s - loss: 0.3117 - accuracy: 0.9047 - val_loss: 0.4615 - val_accuracy: 0.9211
# Epoch 16/250
# 50/50 - 18s - loss: 0.3022 - accuracy: 0.9083 - val_loss: 0.5421 - val_accuracy: 0.7619
# Epoch 17/250
# 50/50 - 25s - loss: 0.3108 - accuracy: 0.9040 - val_loss: 1.3971 - val_accuracy: 0.5995
# Epoch 18/250
# 50/50 - 22s - loss: 0.2935 - accuracy: 0.9117 - val_loss: 0.4026 - val_accuracy: 0.9136
# Epoch 19/250
# 50/50 - 20s - loss: 0.3054 - accuracy: 0.9066 - val_loss: 0.2886 - val_accuracy: 0.9204
# Epoch 20/250
# 50/50 - 19s - loss: 0.2948 - accuracy: 0.9108 - val_loss: 1.4804 - val_accuracy: 0.8128
# Epoch 21/250
# 50/50 - 20s - loss: 0.2952 - accuracy: 0.9115 - val_loss: 0.6371 - val_accuracy: 0.7971
# Epoch 22/250
# 50/50 - 22s - loss: 0.2954 - accuracy: 0.9107 - val_loss: 0.6014 - val_accuracy: 0.9017
# Epoch 23/250
# 50/50 - 20s - loss: 0.2976 - accuracy: 0.9107 - val_loss: 0.6959 - val_accuracy: 0.9207

# %%
baseline_score = model.evaluate(X_test, y_test)
brightness_score = brightness_model.evaluate(X_test, y_test)
bspline_score = bspline_model.evaluate(X_test, y_test)

print("Baseline Model - Test loss:", baseline_score[0], "Test accuracy:", baseline_score[1])
print("Brightness Model - Test loss:", brightness_score[0], "Test accuracy:", brightness_score[1])
print("B-spline Model - Test loss:", bspline_score[0], "Test accuracy:", bspline_score[1])
# Out:
# 1/1 [==============================] - 1s 658ms/step - loss: 2.7501 - accuracy: 0.4117
# 1/1 [==============================] - 1s 757ms/step - loss: 1.8829 - accuracy: 0.3421
# 1/1 [==============================] - 1s 595ms/step - loss: 1.8342 - accuracy: 0.3421
# Baseline Model - Test loss: 2.75014066696167 Test accuracy: 0.41169485449790955
# Brightness Model - Test loss: 1.8829065561294556 Test accuracy: 0.3421109616756439
# B-spline Model - Test loss: 1.8342467546463013 Test accuracy: 0.3421109616756439
